# %% [markdown]
# <a href="https://colab.research.google.com/github/sc7-cloud/TFG---GOOGLE-COLAB-C-DIGOS-/blob/main/ANALISIS_DE_NEGOCIO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


artistas_df = pd.read_excel('/content/Artistas.xlsx')
canciones_df = pd.read_excel('/content/CANCIONES1.xlsx')


print("Primeras filas de la base de datos de Artistas:")
print(artistas_df.head())
print("\nPrimeras filas de la base de datos de Canciones:")
print(canciones_df.head())
# Out:
# Primeras filas de la base de datos de Artistas:
#    Chartmetric ID         Artista  Artista ID            País          Región  \
# 0         1404155      Lola Young        1001     Reino Unido  Western Europe
# 1          470449   Playboi Carti        1002  Estados Unidos   North America
# 2            2007            Akon        1003         Senegal  Western Africa
# 3            3544  Ellie Goulding        1004     Reino Unido  Western Europe
# 4         1202489          GIVĒON        1005  Estados Unidos   North America
#
#       Continente      Solista/Grupo     Género 1    Género 2   Género 3  ...  \
# 0         Europe              Grupo          R&B    Folk Pop      Indie  ...
# 1  North America  Artistas solistas  Hip-Hop/Rap     Pop Rap   Rage Rap  ...
# 2         Africa  Artistas solistas  Hip-Hop/Rap         Pop   R&B/Soul  ...
# 3         Europe  Artistas solistas   Electronic  Electropop  Indie Pop  ...
# ...

# %%
print("Primeras filas de la base de datos de Artistas:")
print(artistas_df.head())
print("\nPrimeras filas de la base de datos de Canciones:")
print(canciones_df.head())


df_combinado = pd.merge(artistas_df, canciones_df, on="Artista ID", how="inner")


print("\nPrimeras filas del DataFrame combinado:")
print(df_combinado.head())


df_combinado['Artista ID'] = df_combinado['Artista ID'].astype('category')



print("\nPrimeras filas después de convertir los identificadores a categóricos:")
print(df_combinado[['Artista ID']].dtypes)



print(merged_df.head())


print(merged_df.isnull().sum())





generos_por_pais = merged_df.groupby(['País_y', 'Género 1']).size().reset_index(name='Repeticiones')


plt.figure(figsize=(12, 8))
sns.barplot(x='Repeticiones', y='País_y', hue='Género 1', data=generos_por_pais, ci=None)
plt.title('Comparación de Géneros Musicales por País')
plt.xlabel('Número de Repeticiones en el Top 50')
plt.ylabel('País')
plt.legend(title='Género Musical', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Primeras filas de la base de datos de Artistas:
#    Chartmetric ID         Artista  Artista ID            País          Región  \
# 0         1404155      Lola Young        1001     Reino Unido  Western Europe
# 1          470449   Playboi Carti        1002  Estados Unidos   North America
# 2            2007            Akon        1003         Senegal  Western Africa
# 3            3544  Ellie Goulding        1004     Reino Unido  Western Europe
# 4         1202489          GIVĒON        1005  Estados Unidos   North America
#
#       Continente      Solista/Grupo     Género 1    Género 2   Género 3  ...  \
# 0         Europe              Grupo          R&B    Folk Pop      Indie  ...
# 1  North America  Artistas solistas  Hip-Hop/Rap     Pop Rap   Rage Rap  ...
# 2         Africa  Artistas solistas  Hip-Hop/Rap         Pop   R&B/Soul  ...
# 3         Europe  Artistas solistas   Electronic  Electropop  Indie Pop  ...
# ...

# %%
print("Géneros únicos:", merged_df['Género 1'].unique())
print("Países únicos:", merged_df['País_x'].unique())


generos_por_pais = merged_df.groupby(['País_x', 'Género 1']).size().reset_index(name='Repeticiones')


print(generos_por_pais.head())


plt.figure(figsize=(12, 8))
sns.barplot(x='Repeticiones', y='País_x', hue='Género 1', data=generos_por_pais, ci=None)


plt.title('Comparación de Géneros Musicales por País')
plt.xlabel('Número de Repeticiones en el Top 50')
plt.ylabel('País')
plt.legend(title='Género Musical', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()


plt.show()
# Out:
# Géneros únicos: ['Chilean Hip-Hop' 'Pop' 'Reggaeton' 'Argentine Hip-Hop' 'Afrobeats' 'Rkt'
#  'Brazilian Hip-Hop' 'Sertanejo' 'Brazilian Funk' 'Pagode' 'Mpb'
#  'Brega Funk' 'Indie Pop' 'Indie' 'Forro' 'Louvores' 'Hip-Hop/Rap'
#  'Chansons' 'Country' 'Country Pop' 'Folk Pop' 'R&B' 'Rock' 'Lofi'
#  'Corridos' 'Trap Latino' 'Dembow' 'Colombian Pop' 'Latin Hip-Hop'
#  'Latin Rock' 'German Hip-Hop' 'Metal' 'Emo' 'Latin Pop' 'Soundtrack'
#  'French Hip-Hop' 'R&B/Soul' 'Italian Rap' 'UK Hip-Hop' 'House' 'Italian'
#  'Opm' 'J-Pop' 'Mexican Hip-Hop' 'Edm' 'Trap']
# Países únicos: ['AR' 'BR' 'CA' 'CO' 'DE' 'ES' 'FR' 'GB' 'IT' 'JP' 'KR' 'MX' 'NL' 'SE'
#  'US']
#   País_x           Género 1  Repeticiones
# 0     AR          Afrobeats            20
# 1     AR  Argentine Hip-Hop            25
# 2     AR    Chilean Hip-Hop            27
# 3     AR                Pop            18
# 4     AR          Reggaeton            11
# <ipython-input-17-04f467b8d1d2>:13: FutureWarning:
#
# ...

# %%
print(artistas_df.head())



sns.pairplot(artistas_df[['Seguidores en TikTok', 'Oyentes mensuales en Spotify', 'Tasa de conversión en Spotify']])
plt.suptitle('Relación entre las métricas de TikTok y Spotify', y=1.02)
plt.tight_layout()
plt.show()


plt.figure(figsize=(8, 6))
sns.scatterplot(x='Seguidores en TikTok', y='Tasa de conversión en Spotify', data=artistas_df)
plt.title('Relación entre Seguidores en TikTok y Tasa de Conversión en Spotify')
plt.xlabel('Seguidores en TikTok')
plt.ylabel('Tasa de Conversión en Spotify')
plt.tight_layout()
plt.show()
# Out:
#    Chartmetric ID         Artista  Artista ID            País          Región  \
# 0         1404155      Lola Young        1001     Reino Unido  Western Europe
# 1          470449   Playboi Carti        1002  Estados Unidos   North America
# 2            2007            Akon        1003         Senegal  Western Africa
# 3            3544  Ellie Goulding        1004     Reino Unido  Western Europe
# 4         1202489          GIVĒON        1005  Estados Unidos   North America
#
#       Continente      Solista/Grupo     Género 1    Género 2   Género 3  ...  \
# 0         Europe              Grupo          R&B    Folk Pop      Indie  ...
# 1  North America  Artistas solistas  Hip-Hop/Rap     Pop Rap   Rage Rap  ...
# 2         Africa  Artistas solistas  Hip-Hop/Rap         Pop   R&B/Soul  ...
# 3         Europe  Artistas solistas   Electronic  Electropop  Indie Pop  ...
# 4  North America  Artistas solistas          R&B         Pop   Neo-Soul  ...
#
# ...
